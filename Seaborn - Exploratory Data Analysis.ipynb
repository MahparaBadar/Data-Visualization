# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
pro = pd.read_csv("property.csv")

# %%
pro.head()
# Out:
#    Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0      1  526301100           20        RL         141.0     31770   Pave
# 1      2  526350040           20        RH          80.0     11622   Pave
# 2      3  526351010           20        RL          81.0     14267   Pave
# 3      4  526353030           20        RL          93.0     11160   Pave
# 4      5  527105010           60        RL          74.0     13830   Pave
#
#   Alley Lot Shape Land Contour  ...  Fence Misc Feature Misc Val Mo Sold  \
# 0   NaN       IR1          Lvl  ...    NaN          NaN        0       5
# 1   NaN       Reg          Lvl  ...  MnPrv          NaN        0       6
# 2   NaN       IR1          Lvl  ...    NaN         Gar2    12500       6
# 3   NaN       Reg          Lvl  ...    NaN          NaN        0       4
# 4   NaN       IR1          Lvl  ...  MnPrv          NaN        0       3
#
#   Yr Sold Sale Type Sale Condition SalePrice           Year            Rooms
# ...

# %% [markdown]
# # Seaborn
#
# * conditional plotting
# * multiple columns on a single chart

# %%
pro.shape
# Out:
# (2930, 84)

# %%
import seaborn as sns

# %%
dir(sns)
# Out:
# ['FacetGrid',
#  'JointGrid',
#  'PairGrid',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_compat',
#  '_core',
#  '_decorators',
#  '_docstrings',
#  '_oldcore',
#  '_orig_rc_params',
#  '_statistics',
#  '_stats',
#  'algorithms',
#  'axes_style',
#  'axisgrid',
#  'barplot',
#  'blend_palette',
#  'boxenplot',
#  'boxplot',
#  'categorical',
#  'catplot',
#  'choose_colorbrewer_palette',
#  'choose_cubehelix_palette',
#  'choose_dark_palette',
#  'choose_diverging_palette',
#  'choose_light_palette',
#  'clustermap',
#  'cm',
#  'color_palette',
#  'colors',
#  'countplot',
#  'crayon_palette',
#  'crayons',
#  'cubehelix_palette',
#  'dark_palette',
#  'desaturate',
#  'despine',
#  'displot',
#  'distplot',
#  'distributions',
#  'diverging_palette',
#  'dogplot',
#  'ecdfplot',
#  'external',
#  'get_data_home',
#  'get_dataset_names',
#  'heatmap',
# ...

# %% [markdown]
# ### relplot
#
# In Seaborn, a scatter plot is referred to as a "relational plot." This term highlights that this type of plot is specifically designed to visualize and explore the relationships or associations between different variables in your data, making it a powerful tool for analyzing patterns and connections within your dataset.

# %% [markdown]
# ### kdeplot
#
# Seaborn's kdeplot function allows you to create a smooth, histogram-like plot, where bars are replaced with a continuous curve. This curve represents the Kernel Density Estimation (KDE) of the data distribution, providing a more nuanced and continuous view of the data compared to traditional histograms, which use discrete bars to represent data points.

# %%
pro.columns
# Out:
# Index(['Order', 'PID', 'MS SubClass', 'MS Zoning', 'Lot Frontage', 'Lot Area',
#        'Street', 'Alley', 'Lot Shape', 'Land Contour', 'Utilities',
#        'Lot Config', 'Land Slope', 'Neighborhood', 'Condition 1',
#        'Condition 2', 'Bldg Type', 'House Style', 'Overall Qual',
#        'Overall Cond', 'Year Built', 'Year Remod/Add', 'Roof Style',
#        'Roof Matl', 'Exterior 1st', 'Exterior 2nd', 'Mas Vnr Type',
#        'Mas Vnr Area', 'Exter Qual', 'Exter Cond', 'Foundation', 'Bsmt Qual',
#        'Bsmt Cond', 'Bsmt Exposure', 'BsmtFin Type 1', 'BsmtFin SF 1',
#        'BsmtFin Type 2', 'BsmtFin SF 2', 'Bsmt Unf SF', 'Total Bsmt SF',
#        'Heating', 'Heating QC', 'Central Air', 'Electrical', '1st Flr SF',
#        '2nd Flr SF', 'Low Qual Fin SF', 'Gr Liv Area', 'Bsmt Full Bath',
#        'Bsmt Half Bath', 'Full Bath', 'Half Bath', 'Bedroom AbvGr',
#        'Kitchen AbvGr', 'Kitchen Qual', 'TotRms AbvGrd', 'Functional',
# ...

# %% [markdown]
# # relplot

# %%
sns.relplot(data = pro, x = 'Gr Liv Area', y = 'SalePrice')

plt.show()

# %% [markdown]
# ## set_theme()

# %%
sns.set_theme()

sns.relplot(data = pro, x = 'Gr Liv Area', y = 'SalePrice')

plt.show()

# %%
sns.set_theme(style = "dark")

sns.relplot(data = pro, x = 'Gr Liv Area', y = 'SalePrice')

plt.show()

# %%
pro.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2930 entries, 0 to 2929
# Data columns (total 84 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Order            2930 non-null   int64
#  1   PID              2930 non-null   int64
#  2   MS SubClass      2930 non-null   int64
#  3   MS Zoning        2930 non-null   object
#  4   Lot Frontage     2440 non-null   float64
#  5   Lot Area         2930 non-null   int64
#  6   Street           2930 non-null   object
#  7   Alley            198 non-null    object
#  8   Lot Shape        2930 non-null   object
#  9   Land Contour     2930 non-null   object
#  10  Utilities        2930 non-null   object
#  11  Lot Config       2930 non-null   object
#  12  Land Slope       2930 non-null   object
#  13  Neighborhood     2930 non-null   object
#  14  Condition 1      2930 non-null   object
#  15  Condition 2      2930 non-null   object
# ...

# %%
pro["Overall Cond"].value_counts()
# Out:
# 5    1654
# 6     533
# 7     390
# 8     144
# 4     101
# 3      50
# 9      41
# 2      10
# 1       7
# Name: Overall Cond, dtype: int64

# %% [markdown]
# ## hue

# %%
sns.set_theme()

sns.relplot(data = pro, x = 'Gr Liv Area', y = 'SalePrice',
           hue = "Overall Cond")

plt.show()

# %%
pro["Rooms"].unique()
# Out:
# array(['7 rooms or more', '6 rooms or less'], dtype=object)

# %%
sns.relplot(data = pro, x = 'Gr Liv Area', y = 'SalePrice',
           hue = "Rooms")

plt.show()

# %% [markdown]
# ## palette
#
# https://matplotlib.org/stable/users/explain/colors/colormaps.html

# %%
sns.set_theme()

sns.relplot(data = pro, x = 'Gr Liv Area', y = 'SalePrice',
           hue = "Overall Cond", palette = "RdYlBu")

plt.show()

# %%
cols = pro.columns

# %%
cols
# Out:
# Index(['Order', 'PID', 'MS SubClass', 'MS Zoning', 'Lot Frontage', 'Lot Area',
#        'Street', 'Alley', 'Lot Shape', 'Land Contour', 'Utilities',
#        'Lot Config', 'Land Slope', 'Neighborhood', 'Condition 1',
#        'Condition 2', 'Bldg Type', 'House Style', 'Overall Qual',
#        'Overall Cond', 'Year Built', 'Year Remod/Add', 'Roof Style',
#        'Roof Matl', 'Exterior 1st', 'Exterior 2nd', 'Mas Vnr Type',
#        'Mas Vnr Area', 'Exter Qual', 'Exter Cond', 'Foundation', 'Bsmt Qual',
#        'Bsmt Cond', 'Bsmt Exposure', 'BsmtFin Type 1', 'BsmtFin SF 1',
#        'BsmtFin Type 2', 'BsmtFin SF 2', 'Bsmt Unf SF', 'Total Bsmt SF',
#        'Heating', 'Heating QC', 'Central Air', 'Electrical', '1st Flr SF',
#        '2nd Flr SF', 'Low Qual Fin SF', 'Gr Liv Area', 'Bsmt Full Bath',
#        'Bsmt Half Bath', 'Full Bath', 'Half Bath', 'Bedroom AbvGr',
#        'Kitchen AbvGr', 'Kitchen Qual', 'TotRms AbvGrd', 'Functional',
# ...

# %% [markdown]
# ## size

# %%
sns.relplot(data = pro, x = 'Gr Liv Area', y = 'SalePrice',
           hue = "Overall Cond", palette = "RdYlBu",
           size = "Garage Area")

plt.show()

# %% [markdown]
# ## sizes

# %%
sns.relplot(data = pro, x = 'Gr Liv Area', y = 'SalePrice',
           hue = "Overall Cond", palette = "RdYlBu",
           size = "Garage Area", sizes = (1, 300))

plt.show()

# %%
sns.relplot(data = pro, x = 'Gr Liv Area', y = 'SalePrice',
           hue = "Overall Cond", palette = "RdYlBu",
           size = "Rooms")    # if we use any categorical data in size (here e.g. Rooms) then we can not pass tuple in "sizes",
                              # then we will have to give list or dictionary b/c tuple is used for the ranges.
                               # range(0, 29)

plt.show()

# %%
sns.relplot(data = pro, x = 'Gr Liv Area', y = 'SalePrice',
           hue = "Overall Cond", palette = "RdYlBu",
           size = "Rooms", sizes =[1, 200])    # if we use any categorical data in size (here e.g. Rooms)
                                               # then we can not pass tuple in "sizes",
                                              # then we will have to give list or dictionary b/c tuple is used for the ranges.
                                              # range(0, 29)

plt.show()

# %%
pro["Rooms"].unique()
# Out:
# array(['7 rooms or more', '6 rooms or less'], dtype=object)

# %%
sns.relplot(data = pro, x = 'Gr Liv Area', y = 'SalePrice',
           hue = "Overall Cond", palette = "RdYlBu",
           size = "Rooms", sizes =[200, 30])    

plt.show()

# %% [markdown]
# ## style

# %%
sns.relplot(data = pro, x = 'Gr Liv Area', y = 'SalePrice',
           hue = "Overall Cond", palette = "RdYlBu",
           size = "Garage Area", sizes = (1, 300),
           style = "Rooms")

plt.show()

# %% [markdown]
# ## markers
#
# https://matplotlib.org/stable/api/markers_api.html

# %%
sns.relplot(data = pro, x = 'Gr Liv Area', y = 'SalePrice',
           hue = "Overall Cond", palette = "RdYlBu",
           size = "Garage Area", sizes = (1, 300),
           style = "Rooms", markers = ["^", "v"])

plt.show()

# %%
cols
# Out:
# Index(['Order', 'PID', 'MS SubClass', 'MS Zoning', 'Lot Frontage', 'Lot Area',
#        'Street', 'Alley', 'Lot Shape', 'Land Contour', 'Utilities',
#        'Lot Config', 'Land Slope', 'Neighborhood', 'Condition 1',
#        'Condition 2', 'Bldg Type', 'House Style', 'Overall Qual',
#        'Overall Cond', 'Year Built', 'Year Remod/Add', 'Roof Style',
#        'Roof Matl', 'Exterior 1st', 'Exterior 2nd', 'Mas Vnr Type',
#        'Mas Vnr Area', 'Exter Qual', 'Exter Cond', 'Foundation', 'Bsmt Qual',
#        'Bsmt Cond', 'Bsmt Exposure', 'BsmtFin Type 1', 'BsmtFin SF 1',
#        'BsmtFin Type 2', 'BsmtFin SF 2', 'Bsmt Unf SF', 'Total Bsmt SF',
#        'Heating', 'Heating QC', 'Central Air', 'Electrical', '1st Flr SF',
#        '2nd Flr SF', 'Low Qual Fin SF', 'Gr Liv Area', 'Bsmt Full Bath',
#        'Bsmt Half Bath', 'Full Bath', 'Half Bath', 'Bedroom AbvGr',
#        'Kitchen AbvGr', 'Kitchen Qual', 'TotRms AbvGrd', 'Functional',
# ...

# %%
pro["Year"].unique()
# Out:
# array(['1999 or older', '2000 or newer'], dtype=object)

# %% [markdown]
# ## col / row

# %%
sns.relplot(data = pro, x = 'Gr Liv Area', y = 'SalePrice',
           hue = "Overall Cond", palette = "RdYlBu",
           size = "Garage Area", sizes = (1, 300),
           style = "Rooms", markers = ["^", "v"], col = "Year")

plt.show()

# %%
sns.relplot(data = pro, x = 'Gr Liv Area', y = 'SalePrice',
           hue = "Overall Cond", palette = "RdYlBu",
           size = "Garage Area", sizes = (1, 300),
           style = "Rooms", col = "Year")

plt.show()

# %%
pro["Sale Type"].unique()
# Out:
# array(['WD ', 'New', 'COD', 'ConLI', 'Con', 'ConLD', 'Oth', 'ConLw',
#        'CWD', 'VWD'], dtype=object)

# %%
pro["Land Slope"].unique()
# Out:
# array(['Gtl', 'Mod', 'Sev'], dtype=object)

# %%
sns.relplot(data = pro, x = 'Gr Liv Area', y = 'SalePrice',
           hue = "Overall Cond", palette = "RdYlBu",
           size = "Garage Area", sizes = (1, 300),
           style = "Rooms", row = "Land Slope", col = "Year")

plt.show()

# %%
pro.shape[0] #0 --> indexing
# Out:
# 2930

# %%
pro.shape[0]*5 # b/c we have used 5 variables in our graph

# we are getting information of 14650 data points in a single graph
# Out:
# 14650

# %%
cols
# Out:
# Index(['Order', 'PID', 'MS SubClass', 'MS Zoning', 'Lot Frontage', 'Lot Area',
#        'Street', 'Alley', 'Lot Shape', 'Land Contour', 'Utilities',
#        'Lot Config', 'Land Slope', 'Neighborhood', 'Condition 1',
#        'Condition 2', 'Bldg Type', 'House Style', 'Overall Qual',
#        'Overall Cond', 'Year Built', 'Year Remod/Add', 'Roof Style',
#        'Roof Matl', 'Exterior 1st', 'Exterior 2nd', 'Mas Vnr Type',
#        'Mas Vnr Area', 'Exter Qual', 'Exter Cond', 'Foundation', 'Bsmt Qual',
#        'Bsmt Cond', 'Bsmt Exposure', 'BsmtFin Type 1', 'BsmtFin SF 1',
#        'BsmtFin Type 2', 'BsmtFin SF 2', 'Bsmt Unf SF', 'Total Bsmt SF',
#        'Heating', 'Heating QC', 'Central Air', 'Electrical', '1st Flr SF',
#        '2nd Flr SF', 'Low Qual Fin SF', 'Gr Liv Area', 'Bsmt Full Bath',
#        'Bsmt Half Bath', 'Full Bath', 'Half Bath', 'Bedroom AbvGr',
#        'Kitchen AbvGr', 'Kitchen Qual', 'TotRms AbvGrd', 'Functional',
# ...
