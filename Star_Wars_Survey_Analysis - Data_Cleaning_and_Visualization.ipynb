# %%
url = "https://github.com/fivethirtyeight/data/blob/master/star-wars-survey/StarWars.csv"

# %%
import requests

# %%
response = requests.get(url)
response
# Out:
# <Response [200]>

# %% [markdown]
# Comma-separated values (CSV) is a text file format that uses commas to separate values. A CSV file stores tabular data (numbers and text) in plain text, where each line of the file typically represents one data record.

# %%
dir(response)
# Out:
# ['__attrs__',
#  '__bool__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__nonzero__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_content',
#  '_content_consumed',
#  '_next',
#  'apparent_encoding',
#  'close',
#  'connection',
#  'content',
#  'cookies',
#  'elapsed',
#  'encoding',
#  'headers',
#  'history',
#  'is_permanent_redirect',
#  'is_redirect',
#  'iter_content',
#  'iter_lines',
#  'json',
#  'links',
#  'next',
#  'ok',
#  'raise_for_status',
#  'raw',
#  'reason',
#  'request',
#  'status_code',
#  'text',
#  'url']

# %%
# response.text

# %%
response.json().keys()
# Out:
# dict_keys(['payload', 'title'])

# %%
# response.json()["payload"]["blob"]['rawLines']

# %%
len(response.json()["payload"]["blob"]['rawLines'])
# Out:
# 1188

# %%
response.json()["payload"]["blob"]['rawLines'][0]
# Out:
# 'RespondentID,Have you seen any of the 6 films in the Star Wars franchise?,Do you consider yourself to be a fan of the Star Wars film franchise?,Which of the following Star Wars films have you seen? Please select all that apply.,,,,,,Please rank the Star Wars films in order of preference with 1 being your favorite film in the franchise and 6 being your least favorite film.,,,,,,"Please state whether you view the following characters favorably, unfavorably, or are unfamiliar with him/her.",,,,,,,,,,,,,,Which character shot first?,Are you familiar with the Expanded Universe?,Do you consider yourself to be a fan of the Expanded Universe?ξ,Do you consider yourself to be a fan of the Star Trek franchise?,Gender,Age,Household Income,Education,Location (Census Region)'

# %%
data = response.json()["payload"]["blob"]['rawLines']

# %%
data[0]
# Out:
# 'RespondentID,Have you seen any of the 6 films in the Star Wars franchise?,Do you consider yourself to be a fan of the Star Wars film franchise?,Which of the following Star Wars films have you seen? Please select all that apply.,,,,,,Please rank the Star Wars films in order of preference with 1 being your favorite film in the franchise and 6 being your least favorite film.,,,,,,"Please state whether you view the following characters favorably, unfavorably, or are unfamiliar with him/her.",,,,,,,,,,,,,,Which character shot first?,Are you familiar with the Expanded Universe?,Do you consider yourself to be a fan of the Expanded Universe?ξ,Do you consider yourself to be a fan of the Star Trek franchise?,Gender,Age,Household Income,Education,Location (Census Region)'

# %%
data[1]
# Out:
# ',Response,Response,Star Wars: Episode I  The Phantom Menace,Star Wars: Episode II  Attack of the Clones,Star Wars: Episode III  Revenge of the Sith,Star Wars: Episode IV  A New Hope,Star Wars: Episode V The Empire Strikes Back,Star Wars: Episode VI Return of the Jedi,Star Wars: Episode I  The Phantom Menace,Star Wars: Episode II  Attack of the Clones,Star Wars: Episode III  Revenge of the Sith,Star Wars: Episode IV  A New Hope,Star Wars: Episode V The Empire Strikes Back,Star Wars: Episode VI Return of the Jedi,Han Solo,Luke Skywalker,Princess Leia Organa,Anakin Skywalker,Obi Wan Kenobi,Emperor Palpatine,Darth Vader,Lando Calrissian,Boba Fett,C-3P0,R2 D2,Jar Jar Binks,Padme Amidala,Yoda,Response,Response,Response,Response,Response,Response,Response,Response,Response'

# %%
data[2]
# Out:
# "3292879998,Yes,Yes,Star Wars: Episode I  The Phantom Menace,Star Wars: Episode II  Attack of the Clones,Star Wars: Episode III  Revenge of the Sith,Star Wars: Episode IV  A New Hope,Star Wars: Episode V The Empire Strikes Back,Star Wars: Episode VI Return of the Jedi,3,2,1,4,5,6,Very favorably,Very favorably,Very favorably,Very favorably,Very favorably,Very favorably,Very favorably,Unfamiliar (N/A),Unfamiliar (N/A),Very favorably,Very favorably,Very favorably,Very favorably,Very favorably,I don't understand this question,Yes,No,No,Male,18-29,,High school degree,South Atlantic"

# %%
# with open("starwars.csv", "w") as f:
#     f.write(data[0])

# %%
# with open("starwars.csv", "a") as f:
#     f.write(data[1])

# %%
# with open("starwars.csv", "a") as f:
#     f.write(data[2])

# %%
with open("star.csv", "a") as f:
    for row in data:
        f.write(row+ "\n")

# %%
import pandas as pd

# %%
star = pd.read_csv("star.csv", encoding = "windows-1251")
star
# Out:
#      RespondentID  \
# 0             NaN
# 1      3292879998
# 2      3292879538
# 3      3292765271
# 4      3292763116
# ...           ...
# 5934   3288388730
# 5935   3288378779
# 5936   3288375286
# 5937   3288373068
# 5938   3288372923
#
#      Have you seen any of the 6 films in the Star Wars franchise?  \
# 0                                              Response
# 1                                                   Yes
# 2                                                    No
# 3                                                   Yes
# 4                                                   Yes
# ...                                                 ...
# 5934                                                Yes
# 5935                                                Yes
# 5936                                                 No
# 5937                                                Yes
# 5938                                                Yes
#
# ...

# %%
star.drop(0)
# Out:
#      RespondentID  \
# 1      3292879998
# 2      3292879538
# 3      3292765271
# 4      3292763116
# 5      3292731220
# ...           ...
# 5934   3288388730
# 5935   3288378779
# 5936   3288375286
# 5937   3288373068
# 5938   3288372923
#
#      Have you seen any of the 6 films in the Star Wars franchise?  \
# 1                                                   Yes
# 2                                                    No
# 3                                                   Yes
# 4                                                   Yes
# 5                                                   Yes
# ...                                                 ...
# 5934                                                Yes
# 5935                                                Yes
# 5936                                                 No
# 5937                                                Yes
# 5938                                                Yes
#
# ...

# %%
star
# Out:
#      RespondentID  \
# 0             NaN
# 1      3292879998
# 2      3292879538
# 3      3292765271
# 4      3292763116
# ...           ...
# 5934   3288388730
# 5935   3288378779
# 5936   3288375286
# 5937   3288373068
# 5938   3288372923
#
#      Have you seen any of the 6 films in the Star Wars franchise?  \
# 0                                              Response
# 1                                                   Yes
# 2                                                    No
# 3                                                   Yes
# 4                                                   Yes
# ...                                                 ...
# 5934                                                Yes
# 5935                                                Yes
# 5936                                                 No
# 5937                                                Yes
# 5938                                                Yes
#
# ...

# %%
star[1:]
# Out:
#      RespondentID  \
# 1      3292879998
# 2      3292879538
# 3      3292765271
# 4      3292763116
# 5      3292731220
# ...           ...
# 5934   3288388730
# 5935   3288378779
# 5936   3288375286
# 5937   3288373068
# 5938   3288372923
#
#      Have you seen any of the 6 films in the Star Wars franchise?  \
# 1                                                   Yes
# 2                                                    No
# 3                                                   Yes
# 4                                                   Yes
# 5                                                   Yes
# ...                                                 ...
# 5934                                                Yes
# 5935                                                Yes
# 5936                                                 No
# 5937                                                Yes
# 5938                                                Yes
#
# ...

# %%
df = star[1:].copy()
df
# Out:
#      RespondentID  \
# 1      3292879998
# 2      3292879538
# 3      3292765271
# 4      3292763116
# 5      3292731220
# ...           ...
# 5934   3288388730
# 5935   3288378779
# 5936   3288375286
# 5937   3288373068
# 5938   3288372923
#
#      Have you seen any of the 6 films in the Star Wars franchise?  \
# 1                                                   Yes
# 2                                                    No
# 3                                                   Yes
# 4                                                   Yes
# 5                                                   Yes
# ...                                                 ...
# 5934                                                Yes
# 5935                                                Yes
# 5936                                                 No
# 5937                                                Yes
# 5938                                                Yes
#
# ...

# %%
df.columns
# Out:
# Index(['RespondentID',
#        'Have you seen any of the 6 films in the Star Wars franchise?',
#        'Do you consider yourself to be a fan of the Star Wars film franchise?',
#        'Which of the following Star Wars films have you seen? Please select all that apply.',
#        'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8',
#        'Please rank the Star Wars films in order of preference with 1 being your favorite film in the franchise and 6 being your least favorite film.',
#        'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
#        'Unnamed: 14',
#        'Please state whether you view the following characters favorably, unfavorably, or are unfamiliar with him/her.',
#        'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19',
#        'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23',
#        'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27',
#        'Unnamed: 28', 'Which character shot first?',
# ...

# %%
df[['RespondentID',
       'Have you seen any of the 6 films in the Star Wars franchise?',
       'Do you consider yourself to be a fan of the Star Wars film franchise?']]
# Out:
#      RespondentID  \
# 1      3292879998
# 2      3292879538
# 3      3292765271
# 4      3292763116
# 5      3292731220
# ...           ...
# 5934   3288388730
# 5935   3288378779
# 5936   3288375286
# 5937   3288373068
# 5938   3288372923
#
#      Have you seen any of the 6 films in the Star Wars franchise?  \
# 1                                                   Yes
# 2                                                    No
# 3                                                   Yes
# 4                                                   Yes
# 5                                                   Yes
# ...                                                 ...
# 5934                                                Yes
# 5935                                                Yes
# 5936                                                 No
# 5937                                                Yes
# 5938                                                Yes
#
# ...

# %%
df.iloc[:, 0:3]
# Out:
#      RespondentID  \
# 1      3292879998
# 2      3292879538
# 3      3292765271
# 4      3292763116
# 5      3292731220
# ...           ...
# 5934   3288388730
# 5935   3288378779
# 5936   3288375286
# 5937   3288373068
# 5938   3288372923
#
#      Have you seen any of the 6 films in the Star Wars franchise?  \
# 1                                                   Yes
# 2                                                    No
# 3                                                   Yes
# 4                                                   Yes
# 5                                                   Yes
# ...                                                 ...
# 5934                                                Yes
# 5935                                                Yes
# 5936                                                 No
# 5937                                                Yes
# 5938                                                Yes
#
# ...

# %%
cleaned = df.iloc[:, 0:3]
cleaned
# Out:
#      RespondentID  \
# 1      3292879998
# 2      3292879538
# 3      3292765271
# 4      3292763116
# 5      3292731220
# ...           ...
# 5934   3288388730
# 5935   3288378779
# 5936   3288375286
# 5937   3288373068
# 5938   3288372923
#
#      Have you seen any of the 6 films in the Star Wars franchise?  \
# 1                                                   Yes
# 2                                                    No
# 3                                                   Yes
# 4                                                   Yes
# 5                                                   Yes
# ...                                                 ...
# 5934                                                Yes
# 5935                                                Yes
# 5936                                                 No
# 5937                                                Yes
# 5938                                                Yes
#
# ...

# %%
mapping = {"Yes":True, "No":False}

# %%
cleaned["Have you seen any of the 6 films in the Star Wars franchise?"].map(mapping)
# Out:
# 1        True
# 2       False
# 3        True
# 4        True
# 5        True
#         ...
# 5934     True
# 5935     True
# 5936    False
# 5937     True
# 5938     True
# Name: Have you seen any of the 6 films in the Star Wars franchise?, Length: 5938, dtype: object

# %%
cleaned.iloc[:,1] = cleaned["Have you seen any of the 6 films in the Star Wars franchise?"].map(mapping)

# cleaned.iloc[:,1] = cleaned.iloc[:,1].map(mapping)
# Out:
# C:\Users\hp 840g6\AppData\Local\Temp\ipykernel_7732\1069353180.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned.iloc[:,1] = cleaned["Have you seen any of the 6 films in the Star Wars franchise?"].map(mapping)

# %%
cleaned
# Out:
#      RespondentID  \
# 1      3292879998
# 2      3292879538
# 3      3292765271
# 4      3292763116
# 5      3292731220
# ...           ...
# 5934   3288388730
# 5935   3288378779
# 5936   3288375286
# 5937   3288373068
# 5938   3288372923
#
#      Have you seen any of the 6 films in the Star Wars franchise?  \
# 1                                                  True
# 2                                                 False
# 3                                                  True
# 4                                                  True
# 5                                                  True
# ...                                                 ...
# 5934                                               True
# 5935                                               True
# 5936                                              False
# 5937                                               True
# 5938                                               True
#
# ...

# %%
cleaned.iloc[:,2] = cleaned.iloc[:,2].map(mapping)
# Out:
# C:\Users\hp 840g6\AppData\Local\Temp\ipykernel_7732\3904104162.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned.iloc[:,2] = cleaned.iloc[:,2].map(mapping)

# %%
cleaned
# Out:
#      RespondentID  \
# 1      3292879998
# 2      3292879538
# 3      3292765271
# 4      3292763116
# 5      3292731220
# ...           ...
# 5934   3288388730
# 5935   3288378779
# 5936   3288375286
# 5937   3288373068
# 5938   3288372923
#
#      Have you seen any of the 6 films in the Star Wars franchise?  \
# 1                                                  True
# 2                                                 False
# 3                                                  True
# 4                                                  True
# 5                                                  True
# ...                                                 ...
# 5934                                               True
# 5935                                               True
# 5936                                              False
# 5937                                               True
# 5938                                               True
#
# ...

# %%
renamed = ["id", "seen_any?", "fan?"]

cleaned.columns
# Out:
# Index(['RespondentID',
#        'Have you seen any of the 6 films in the Star Wars franchise?',
#        'Do you consider yourself to be a fan of the Star Wars film franchise?'],
#       dtype='object')

# %%
zip(cleaned.columns, renamed)

# %%
dict(zip(cleaned.columns, renamed))
# Out:
# {'RespondentID': 'id',
#  'Have you seen any of the 6 films in the Star Wars franchise?': 'seen_any?',
#  'Do you consider yourself to be a fan of the Star Wars film franchise?': 'fan?'}

# %%
renamed_dict = dict(zip(cleaned.columns, renamed))
renamed_dict
# Out:
# {'RespondentID': 'id',
#  'Have you seen any of the 6 films in the Star Wars franchise?': 'seen_any?',
#  'Do you consider yourself to be a fan of the Star Wars film franchise?': 'fan?'}

# %%
cleaned.rename(renamed_dict, axis = 1)
# Out:
#               id seen_any?   fan?
# 1     3292879998      True   True
# 2     3292879538     False    NaN
# 3     3292765271      True  False
# 4     3292763116      True   True
# 5     3292731220      True   True
# ...          ...       ...    ...
# 5934  3288388730      True   True
# 5935  3288378779      True   True
# 5936  3288375286     False    NaN
# 5937  3288373068      True   True
# 5938  3288372923      True  False
#
# [5938 rows x 3 columns]

# %%
cleaned.columns = renamed

# %%
cleaned
# Out:
#               id seen_any?   fan?
# 1     3292879998      True   True
# 2     3292879538     False    NaN
# 3     3292765271      True  False
# 4     3292763116      True   True
# 5     3292731220      True   True
# ...          ...       ...    ...
# 5934  3288388730      True   True
# 5935  3288378779      True   True
# 5936  3288375286     False    NaN
# 5937  3288373068      True   True
# 5938  3288372923      True  False
#
# [5938 rows x 3 columns]

# %%
cleaned["seen_any?"].value_counts()
# Out:
# True     4680
# False    1250
# Name: seen_any?, dtype: int64

# %%
cleaned.iloc[:, 1:].value_counts()
# Out:
# seen_any?  fan?
# True       True     2760
#            False    1420
# dtype: int64

# %%
cleaned.iloc[:, 1:].apply(pd.value_counts, axis = "index") # axis = 0 or "index" / by default
# Out:
#        seen_any?  fan?
# True        4680  2760
# False       1250  1420

# %%
df.iloc[:, 3:9]
# Out:
#      Which of the following Star Wars films have you seen? Please select all that apply.  \
# 1              Star Wars: Episode I  The Phantom Menace
# 2                                                   NaN
# 3              Star Wars: Episode I  The Phantom Menace
# 4              Star Wars: Episode I  The Phantom Menace
# 5              Star Wars: Episode I  The Phantom Menace
# ...                                                 ...
# 5934           Star Wars: Episode I  The Phantom Menace
# 5935           Star Wars: Episode I  The Phantom Menace
# 5936                                                NaN
# 5937           Star Wars: Episode I  The Phantom Menace
# 5938           Star Wars: Episode I  The Phantom Menace
#
#                                        Unnamed: 4  \
# 1     Star Wars: Episode II  Attack of the Clones
# 2                                             NaN
# 3     Star Wars: Episode II  Attack of the Clones
# 4     Star Wars: Episode II  Attack of the Clones
# ...

# %%
seen = df.iloc[:, 3:9]

# %%
seen.columns = ["seen_episode1", "seen_episode2",
               "seen_episode3", "seen_episode4",
               "seen_episode5", "seen_episode6"]

# %%
seen
# Out:
#                                  seen_episode1  \
# 1     Star Wars: Episode I  The Phantom Menace
# 2                                          NaN
# 3     Star Wars: Episode I  The Phantom Menace
# 4     Star Wars: Episode I  The Phantom Menace
# 5     Star Wars: Episode I  The Phantom Menace
# ...                                        ...
# 5934  Star Wars: Episode I  The Phantom Menace
# 5935  Star Wars: Episode I  The Phantom Menace
# 5936                                       NaN
# 5937  Star Wars: Episode I  The Phantom Menace
# 5938  Star Wars: Episode I  The Phantom Menace
#
#                                     seen_episode2  \
# 1     Star Wars: Episode II  Attack of the Clones
# 2                                             NaN
# 3     Star Wars: Episode II  Attack of the Clones
# 4     Star Wars: Episode II  Attack of the Clones
# 5     Star Wars: Episode II  Attack of the Clones
# ...                                           ...
# ...

# %%
seen.notnull()
# Out:
#       seen_episode1  seen_episode2  seen_episode3  seen_episode4  \
# 1              True           True           True           True
# 2             False          False          False          False
# 3              True           True           True          False
# 4              True           True           True           True
# 5              True           True           True           True
# ...             ...            ...            ...            ...
# 5934           True           True           True           True
# 5935           True           True           True           True
# 5936          False          False          False          False
# 5937           True           True           True           True
# 5938           True           True          False          False
#
#       seen_episode5  seen_episode6
# 1              True           True
# 2             False          False
# 3             False          False
# 4              True           True
# ...

# %%
seen = seen.notnull()

# %%
cleaned
# Out:
#               id seen_any?   fan?
# 1     3292879998      True   True
# 2     3292879538     False    NaN
# 3     3292765271      True  False
# 4     3292763116      True   True
# 5     3292731220      True   True
# ...          ...       ...    ...
# 5934  3288388730      True   True
# 5935  3288378779      True   True
# 5936  3288375286     False    NaN
# 5937  3288373068      True   True
# 5938  3288372923      True  False
#
# [5938 rows x 3 columns]

# %%
df.iloc[:, 9:15]
# Out:
#      Please rank the Star Wars films in order of preference with 1 being your favorite film in the franchise and 6 being your least favorite film.  \
# 1                                                     3
# 2                                                   NaN
# 3                                                     1
# 4                                                     5
# 5                                                     5
# ...                                                 ...
# 5934                                                  5
# 5935                                                  4
# 5936                                                NaN
# 5937                                                  4
# 5938                                                  6
#
#      Unnamed: 10 Unnamed: 11 Unnamed: 12 Unnamed: 13 Unnamed: 14
# 1              2           1           4           5           6
# 2            NaN         NaN         NaN         NaN         NaN
# ...

# %%
ranking = df.iloc[:, 9:15].copy()

# %%
ranking
# Out:
#      Please rank the Star Wars films in order of preference with 1 being your favorite film in the franchise and 6 being your least favorite film.  \
# 1                                                     3
# 2                                                   NaN
# 3                                                     1
# 4                                                     5
# 5                                                     5
# ...                                                 ...
# 5934                                                  5
# 5935                                                  4
# 5936                                                NaN
# 5937                                                  4
# 5938                                                  6
#
#      Unnamed: 10 Unnamed: 11 Unnamed: 12 Unnamed: 13 Unnamed: 14
# 1              2           1           4           5           6
# 2            NaN         NaN         NaN         NaN         NaN
# ...

# %%
ranking.columns
# Out:
# Index(['Please rank the Star Wars films in order of preference with 1 being your favorite film in the franchise and 6 being your least favorite film.',
#        'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
#        'Unnamed: 14'],
#       dtype='object')

# %%
ranking.columns = ["ranking_"+str(i) for i in range(1, 7)]    # list comprehension
ranking
# Out:
#      ranking_1 ranking_2 ranking_3 ranking_4 ranking_5 ranking_6
# 1            3         2         1         4         5         6
# 2          NaN       NaN       NaN       NaN       NaN       NaN
# 3            1         2         3         4         5         6
# 4            5         6         1         2         4         3
# 5            5         4         6         2         1         3
# ...        ...       ...       ...       ...       ...       ...
# 5934         5         4         6         3         2         1
# 5935         4         5         6         2         3         1
# 5936       NaN       NaN       NaN       NaN       NaN       NaN
# 5937         4         3         6         5         2         1
# 5938         6         1         2         3         4         5
#
# [5938 rows x 6 columns]

# %%
ranking.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5938 entries, 1 to 5938
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ranking_1  4183 non-null   object
#  1   ranking_2  4184 non-null   object
#  2   ranking_3  4179 non-null   object
#  3   ranking_4  4184 non-null   object
#  4   ranking_5  4184 non-null   object
#  5   ranking_6  4184 non-null   object
# dtypes: object(6)
# memory usage: 278.5+ KB

# %%
ranking.astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 ranking.astype(int)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py:6240, in NDFrame.astype(self, dtype, copy, errors)
#    6233     results = [
#    6234         self.iloc[:, i].astype(dtype, copy=copy)
#    6235         for i in range(len(self.columns))
#    6236     ]
#    6238 else:
#    6239     # else, only a single dtype is given
# -> 6240     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241     return self._constructor(new_data).__finalize__(self, method="astype")
#    6243 # GH 33113: handle empty frame or series
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:448, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...

# %%
ranking.astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 ranking.astype(float)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py:6240, in NDFrame.astype(self, dtype, copy, errors)
#    6233     results = [
#    6234         self.iloc[:, i].astype(dtype, copy=copy)
#    6235         for i in range(len(self.columns))
#    6236     ]
#    6238 else:
#    6239     # else, only a single dtype is given
# -> 6240     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241     return self._constructor(new_data).__finalize__(self, method="astype")
#    6243 # GH 33113: handle empty frame or series
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:448, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...

# %%
ranking.ranking_1.value_counts()
# Out:
# 4.0    1185
# 6.0     840
# 3.0     650
# 1.0     645
# 5.0     500
# 2.0     355
# 0.0       8
# Name: ranking_1, dtype: int64

# %%
# ranking.ranking_1 = ranking.ranking_1.str.replace("Please rank the Star Wars films in order of preference with 1 being your favorite film in the franchise and 6 being your least favorite film.", "0")
# ranking.ranking_1

# %%
ranking.ranking_1 = ranking.ranking_1.str.replace("Star Wars: Episode I  The Phantom Menace", "0")
ranking.ranking_1
# Out:
# 1         3
# 2       NaN
# 3         1
# 4         5
# 5         5
#        ...
# 5934      5
# 5935      4
# 5936    NaN
# 5937      4
# 5938      6
# Name: ranking_1, Length: 5938, dtype: object

# %%
ranking.ranking_1 = ranking.ranking_1.astype(float)
ranking.ranking_1
# Out:
# 1       3.0
# 2       NaN
# 3       1.0
# 4       5.0
# 5       5.0
#        ...
# 5934    5.0
# 5935    4.0
# 5936    NaN
# 5937    4.0
# 5938    6.0
# Name: ranking_1, Length: 5938, dtype: float64

# %%
ranking.ranking_2.value_counts()
# Out:
# 5.0    1500
# 4.0     915
# 2.0     580
# 3.0     515
# 6.0     510
# 1.0     160
# Name: ranking_2, dtype: int64

# %%
ranking.ranking_2 = ranking.ranking_2.str.replace("Star Wars: Episode II  Attack of the Clones", "NaN")
ranking.ranking_2
# Out:
# 1         2
# 2       NaN
# 3         2
# 4         6
# 5         4
#        ...
# 5934      4
# 5935      5
# 5936    NaN
# 5937      3
# 5938      1
# Name: ranking_2, Length: 5938, dtype: object

# %%
ranking.ranking_2 = ranking.ranking_2.astype(float)
ranking.ranking_2
# Out:
# 1       2.0
# 2       NaN
# 3       2.0
# 4       6.0
# 5       4.0
#        ...
# 5934    4.0
# 5935    5.0
# 5936    NaN
# 5937    3.0
# 5938    1.0
# Name: ranking_2, Length: 5938, dtype: float64

# %%
ranking.ranking_3.value_counts()
# Out:
# 6                                              1085
# 5                                              1015
# 4                                               910
# 3                                               750
# 2                                               235
# 1                                               180
# Star Wars: Episode III  Revenge of the Sith       4
# Name: ranking_3, dtype: int64

# %%
ranking.ranking_3 = ranking.ranking_3.str.replace("Star Wars: Episode III  Revenge of the Sith", "NaN")
ranking.ranking_3
# Out:
# 1         1
# 2       NaN
# 3         3
# 4         1
# 5         6
#        ...
# 5934      6
# 5935      6
# 5936    NaN
# 5937      6
# 5938      2
# Name: ranking_3, Length: 5938, dtype: object

# %%
ranking.ranking_3 = ranking.ranking_3.astype(float)
ranking.ranking_3
# Out:
# 1       1.0
# 2       NaN
# 3       3.0
# 4       1.0
# 5       6.0
#        ...
# 5934    6.0
# 5935    6.0
# 5936    NaN
# 5937    6.0
# 5938    2.0
# Name: ranking_3, Length: 5938, dtype: float64

# %%
ranking.ranking_4.value_counts()
# Out:
# 1                                    1020
# 6                                     805
# 2                                     675
# 4                                     650
# 3                                     635
# 5                                     395
# Star Wars: Episode IV  A New Hope       4
# Name: ranking_4, dtype: int64

# %%
ranking.ranking_4 = ranking.ranking_4.str.replace("Star Wars: Episode IV  A New Hope", "NaN")
ranking.ranking_4
# Out:
# 1         4
# 2       NaN
# 3         4
# 4         2
# 5         2
#        ...
# 5934      3
# 5935      2
# 5936    NaN
# 5937      5
# 5938      3
# Name: ranking_4, Length: 5938, dtype: object

# %%
ranking.ranking_4 = ranking.ranking_4.astype(float)
ranking.ranking_4
# Out:
# 1       4.0
# 2       NaN
# 3       4.0
# 4       2.0
# 5       2.0
#        ...
# 5934    3.0
# 5935    2.0
# 5936    NaN
# 5937    5.0
# 5938    3.0
# Name: ranking_4, Length: 5938, dtype: float64

# %%
ranking.ranking_5.value_counts()
# Out:
# 1                                               1445
# 2                                               1175
# 5                                                590
# 3                                                530
# 4                                                235
# 6                                                205
# Star Wars: Episode V The Empire Strikes Back       4
# Name: ranking_5, dtype: int64

# %%
ranking.ranking_5 = ranking.ranking_5.str.replace("Star Wars: Episode V The Empire Strikes Back", "NaN")
ranking.ranking_5
# Out:
# 1         5
# 2       NaN
# 3         5
# 4         4
# 5         1
#        ...
# 5934      2
# 5935      3
# 5936    NaN
# 5937      2
# 5938      4
# Name: ranking_5, Length: 5938, dtype: object

# %%
ranking.ranking_5 = ranking.ranking_5.astype(float)
ranking.ranking_5
# Out:
# 1       5.0
# 2       NaN
# 3       5.0
# 4       4.0
# 5       1.0
#        ...
# 5934    2.0
# 5935    3.0
# 5936    NaN
# 5937    2.0
# 5938    4.0
# Name: ranking_5, Length: 5938, dtype: float64

# %%
ranking.ranking_6.value_counts()
# Out:
# 2                                           1160
# 3                                           1100
# 1                                            730
# 6                                            725
# 4                                            285
# 5                                            180
# Star Wars: Episode VI Return of the Jedi       4
# Name: ranking_6, dtype: int64

# %%
ranking.ranking_6 = ranking.ranking_6.str.replace("Star Wars: Episode V The Empire Strikes Back", "NaN")

ranking.ranking_6 = ranking.ranking_5.astype(float)
ranking.ranking_6
# Out:
# 1       5.0
# 2       NaN
# 3       5.0
# 4       4.0
# 5       1.0
#        ...
# 5934    2.0
# 5935    3.0
# 5936    NaN
# 5937    2.0
# 5938    4.0
# Name: ranking_6, Length: 5938, dtype: float64

# %%
ranking.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5938 entries, 1 to 5938
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ranking_1  4183 non-null   float64
#  1   ranking_2  4180 non-null   float64
#  2   ranking_3  4175 non-null   float64
#  3   ranking_4  4180 non-null   float64
#  4   ranking_5  4180 non-null   float64
#  5   ranking_6  4180 non-null   float64
# dtypes: float64(6)
# memory usage: 278.5 KB

# %% [markdown]
# * cleaned
# * seen
# * ranking

# %%
pd.concat([cleaned, seen, ranking])
# Out:
#               id seen_any?   fan? seen_episode1 seen_episode2 seen_episode3  \
# 1     3292879998      True   True           NaN           NaN           NaN
# 2     3292879538     False    NaN           NaN           NaN           NaN
# 3     3292765271      True  False           NaN           NaN           NaN
# 4     3292763116      True   True           NaN           NaN           NaN
# 5     3292731220      True   True           NaN           NaN           NaN
# ...          ...       ...    ...           ...           ...           ...
# 5934         NaN       NaN    NaN           NaN           NaN           NaN
# 5935         NaN       NaN    NaN           NaN           NaN           NaN
# 5936         NaN       NaN    NaN           NaN           NaN           NaN
# 5937         NaN       NaN    NaN           NaN           NaN           NaN
# 5938         NaN       NaN    NaN           NaN           NaN           NaN
#
# ...

# %%
final = cleaned.merge(seen, left_index = True, right_index = True)

# %%
final = final.merge(ranking, left_index=True, right_index=True)

# %%
final
# Out:
#               id seen_any?   fan?  seen_episode1  seen_episode2  \
# 1     3292879998      True   True           True           True
# 2     3292879538     False    NaN          False          False
# 3     3292765271      True  False           True           True
# 4     3292763116      True   True           True           True
# 5     3292731220      True   True           True           True
# ...          ...       ...    ...            ...            ...
# 5934  3288388730      True   True           True           True
# 5935  3288378779      True   True           True           True
# 5936  3288375286     False    NaN          False          False
# 5937  3288373068      True   True           True           True
# 5938  3288372923      True  False           True           True
#
#       seen_episode3  seen_episode4  seen_episode5  seen_episode6  ranking_1  \
# 1              True           True           True           True        3.0
# ...

# %%
df.iloc[:,:15]
# Out:
#      RespondentID  \
# 1      3292879998
# 2      3292879538
# 3      3292765271
# 4      3292763116
# 5      3292731220
# ...           ...
# 5934   3288388730
# 5935   3288378779
# 5936   3288375286
# 5937   3288373068
# 5938   3288372923
#
#      Have you seen any of the 6 films in the Star Wars franchise?  \
# 1                                                  True
# 2                                                 False
# 3                                                  True
# 4                                                  True
# 5                                                  True
# ...                                                 ...
# 5934                                               True
# 5935                                               True
# 5936                                              False
# 5937                                               True
# 5938                                               True
#
# ...

# %%
cleaned.iloc[:, 1:].apply(pd.value_counts(normalize =  True), axis = "index")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[115], line 1
# ----> 1 cleaned.iloc[:, 1:].apply(pd.value_counts(normalize =  True), axis = "index")
#
# TypeError: value_counts() missing 1 required positional argument: 'values'

# %%
cleaned.iloc[:, 1:].apply(lambda col:col.value_counts(normalize = True), axis = 0)
# Out:
#        seen_any?      fan?
# True    0.789207  0.660287
# False   0.210793  0.339713

# %%
cleaned.iloc[:, 1:].apply(lambda col:col.value_counts(normalize = True), axis = 0)*100
# Out:
#        seen_any?       fan?
# True   78.920742  66.028708
# False  21.079258  33.971292

# %%
final.iloc[:,1:3]["seen_any?"].value_counts(normalize = True)*100
# Out:
# True     78.920742
# False    21.079258
# Name: seen_any?, dtype: float64

# %%
def perc(col):
    return col.value_counts(normalize = True)*100

# %%
final.iloc[:,1:3].apply(perc)
# Out:
#        seen_any?       fan?
# True   78.920742  66.028708
# False  21.079258  33.971292

# %%
final.iloc[:,1:3].apply(lambda col:col.value_counts(normalize = True))*100
# Out:
#        seen_any?       fan?
# True   78.920742  66.028708
# False  21.079258  33.971292

# %%
final.iloc[:,1:9].apply(lambda col:col.value_counts(normalize = True))*100
# Out:
#        seen_any?       fan?  seen_episode1  seen_episode2  seen_episode3  \
# False  21.079258  33.971292      43.196362      51.852476      53.620748
# True   78.920742  66.028708      56.803638      48.147524      46.379252
#
#        seen_episode4  seen_episode5  seen_episode6
# False      48.821152      36.106433      37.790502
# True       51.178848      63.893567      62.209498

# %%
percentages = final.iloc[:,1:9].apply(lambda col:col.value_counts(normalize = True))*100

# %%
import matplotlib.pyplot as plt

# %%
percentages.plot.bar()
plt.show()

# %%
percentages.loc[True].plot.bar()
plt.show()

# %%
percentages.loc[True].plot.barh()
plt.show()

# %%
final.iloc[:,9:].mean()
# Out:
# ranking_1    3.725795
# ranking_2    4.087321
# ranking_3    4.341317
# ranking_4    3.272727
# ranking_5    2.513158
# ranking_6    2.513158
# dtype: float64

# %%
final.iloc[:,9:].mean().plot.barh()
plt.show()

# %%
final.iloc[:,9:].max()
# Out:
# ranking_1    6.0
# ranking_2    6.0
# ranking_3    6.0
# ranking_4    6.0
# ranking_5    6.0
# ranking_6    6.0
# dtype: float64

# %%
df.columns
# Out:
# Index(['RespondentID',
#        'Have you seen any of the 6 films in the Star Wars franchise?',
#        'Do you consider yourself to be a fan of the Star Wars film franchise?',
#        'Which of the following Star Wars films have you seen? Please select all that apply.',
#        'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8',
#        'Please rank the Star Wars films in order of preference with 1 being your favorite film in the franchise and 6 being your least favorite film.',
#        'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
#        'Unnamed: 14',
#        'Please state whether you view the following characters favorably, unfavorably, or are unfamiliar with him/her.',
#        'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19',
#        'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23',
#        'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27',
#        'Unnamed: 28', 'Which character shot first?',
# ...

# %%
df["Gender"]
# Out:
# 1         Male
# 2         Male
# 3         Male
# 4         Male
# 5         Male
#          ...
# 5934    Female
# 5935    Female
# 5936    Female
# 5937    Female
# 5938    Female
# Name: Gender, Length: 5938, dtype: object

# %%
male_bol = df["Gender"] == "Male"
female_bol = df["Gender"] == "Female"

# %%
final[male_bol]
# Out:
#               id seen_any?   fan?  seen_episode1  seen_episode2  \
# 1     3292879998      True   True           True           True
# 2     3292879538     False    NaN          False          False
# 3     3292765271      True  False           True           True
# 4     3292763116      True   True           True           True
# 5     3292731220      True   True           True           True
# ...          ...       ...    ...            ...            ...
# 5906  3288429390     False    NaN          False          False
# 5910  3288423088     False    NaN          False          False
# 5917  3288415166      True  False           True           True
# 5922  3288408698      True   True           True          False
# 5930  3288396374      True  False           True           True
#
#       seen_episode3  seen_episode4  seen_episode5  seen_episode6  ranking_1  \
# 1              True           True           True           True        3.0
# ...

# %%
male = final[male_bol]
female = final[female_bol]

# %%
print(male.shape, female.shape)
# Out:
# (2485, 15) (2745, 15)

# %%
print(male.shape[0]+ female.shape[0])
# Out:
# 5230

# %%
df["Gender"].value_counts()
# Out:
# Female      2745
# Male        2485
# Gender         4
# Response       4
# Name: Gender, dtype: int64

# %%
df["Gender"].value_counts(dropna = False)
# Out:
# Female      2745
# Male        2485
# NaN          700
# Gender         4
# Response       4
# Name: Gender, dtype: int64

# %%
male.iloc[:,9:].mean().plot.barh()
plt.show()

# %%
female.iloc[:,9:].mean().plot.barh()
plt.show()

# %%
male.iloc[:,9:].mean().plot.barh(label = "Male")
female.iloc[:,9:].mean().plot.barh(label = "Female", color = "#b00b1e", width = 0.2)
plt.legend()
plt.show()
