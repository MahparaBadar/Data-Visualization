# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
wnba = pd.read_csv("wnba.csv")

# %%
wnba.head()
# Out:
#               Name Team  Pos  Height  Weight        BMI Birth_Place  \
# 0    Aerial Powers  DAL    F     183    71.0  21.200991          US
# 1      Alana Beard   LA  G/F     185    73.0  21.329438          US
# 2     Alex Bentley  CON    G     170    69.0  23.875433          US
# 3  Alex Montgomery  SAN  G/F     185    84.0  24.543462          US
# 4     Alexis Jones  MIN    G     175    78.0  25.469388          US
#
#            Birthdate  Age         College  ... OREB  DREB  REB  AST  STL  BLK  \
# 0   January 17, 1994   23  Michigan State  ...    6    22   28   12    3    6
# 1       May 14, 1982   35            Duke  ...   19    82  101   72   63   13
# 2   October 27, 1990   26      Penn State  ...    4    36   40   78   22    3
# 3  December 11, 1988   28    Georgia Tech  ...   35   134  169   65   20   10
# 4     August 5, 1994   23          Baylor  ...    3     9   12   12    7    0
#
#    TO  PTS  DD2  TD3
# 0  12   93    0    0
# 1  40  217    0    0
# 2  24  218    0    0
# 3  38  188    2    0
# 4  14   50    0    0
#
# [5 rows x 32 columns]

# %%
wnba.columns
# Out:
# Index(['Name', 'Team', 'Pos', 'Height', 'Weight', 'BMI', 'Birth_Place',
#        'Birthdate', 'Age', 'College', 'Experience', 'Games Played', 'MIN',
#        'FGM', 'FGA', 'FG%', '15:00', '3PA', '3P%', 'FTM', 'FTA', 'FT%', 'OREB',
#        'DREB', 'REB', 'AST', 'STL', 'BLK', 'TO', 'PTS', 'DD2', 'TD3'],
#       dtype='object')

# %%
wnba["Experience"].value_counts().sort_index()  # R = rookie (freshies)
# Out:
# 1     12
# 10     5
# 11     4
# 12     4
# 13     3
# 14     3
# 15     2
# 2     11
# 3     19
# 4     11
# 5     14
# 6     14
# 7      4
# 8      3
# 9     11
# R     23
# Name: Experience, dtype: int64

# %%
wnba["Experience"] = wnba["Experience"].str.replace("R", "0").astype(int)

# %%
wnba["Experience"].value_counts().sort_index()
# Out:
# 0     23
# 1     12
# 2     11
# 3     19
# 4     11
# 5     14
# 6     14
# 7      4
# 8      3
# 9     11
# 10     5
# 11     4
# 12     4
# 13     3
# 14     3
# 15     2
# Name: Experience, dtype: int64

# %%
# difference, direction size 
# ratio and interval data type

# %%
def exp_ord(exp):
    if exp == 0:
        return "Rookie"
    elif exp in range(1, 4):
        return "Little Experience"
    elif exp in [4, 5]:
        return "Experienced"
    elif exp in range(6, 11):
        return "Very Experienced"
    else:
        return "Veteran"

# %%
wnba["Experience"].shape
# Out:
# (143,)

# %%
wnba["Experience"]
# Out:
# 0       2
# 1      12
# 2       4
# 3       6
# 4       0
#        ..
# 138     6
# 139     9
# 140     2
# 141     8
# 142     2
# Name: Experience, Length: 143, dtype: int32

# %%
wnba["Experience"].apply(exp_ord)
# Out:
# 0      Little Experience
# 1                Veteran
# 2            Experienced
# 3       Very Experienced
# 4                 Rookie
#              ...
# 138     Very Experienced
# 139     Very Experienced
# 140    Little Experience
# 141     Very Experienced
# 142    Little Experience
# Name: Experience, Length: 143, dtype: object

# %%
wnba["Exp_Ord"] = wnba["Experience"].apply(exp_ord)

# %%
wnba["Exp_Ord"].value_counts()
# Out:
# Little Experience    42
# Very Experienced     37
# Experienced          25
# Rookie               23
# Veteran              16
# Name: Exp_Ord, dtype: int64

# %%
wnba["Exp_Ord"].value_counts().iloc[[-2, 0, 2, 1, -1]]
# Out:
# Rookie               23
# Little Experience    42
# Experienced          25
# Very Experienced     37
# Veteran              16
# Name: Exp_Ord, dtype: int64

# %%
wnba["Exp_Ord"].value_counts().iloc[[-2, 0, 2, 1, -1]].plot.barh(title = "No. of Players in WNBA by Level of Experience")
plt.show()

# %% [markdown]
# # Pie Chart

# %%
wnba["Exp_Ord"].value_counts().iloc[[-2, 0, 2, 1, -1]].plot.pie(title = "No. of Players in WNBA by Level of Experience")
plt.show()

# %%
wnba["Exp_Ord"].value_counts().iloc[[-2, 0, 2, 1, -1]].plot.pie(explode = [0, 0.1, 0, 0.1, 0], title = "No. of Players in WNBA by Level of Experience")
plt.show()

# %%
wnba["Exp_Ord"].value_counts().iloc[[-2, 0, 2, 1, -1]].plot.pie(explode = [0, 0.1, 0, 0.1, 0], autopct = "%.2f%%",
                                                                title = "No. of Players in WNBA by Level of Experience")
plt.show()

# %%
wnba["Exp_Ord"].value_counts(normalize = True).iloc[[-2, 0, 2, 1, -1]]*100
# Out:
# Rookie               16.083916
# Little Experience    29.370629
# Experienced          17.482517
# Very Experienced     25.874126
# Veteran              11.188811
# Name: Exp_Ord, dtype: float64

# %%
wnba["Exp_Ord"].value_counts().iloc[[-2, 0, 2, 1, -1]].plot.pie(explode = [0, 0.08, 0, 0.1, 0], autopct = "%.2f%%",
                                                                title = "No. of Players in WNBA by Level of Experience")

plt.ylabel("")

plt.show()

# %%
wnba.columns
# Out:
# Index(['Name', 'Team', 'Pos', 'Height', 'Weight', 'BMI', 'Birth_Place',
#        'Birthdate', 'Age', 'College', 'Experience', 'Games Played', 'MIN',
#        'FGM', 'FGA', 'FG%', '15:00', '3PA', '3P%', 'FTM', 'FTA', 'FT%', 'OREB',
#        'DREB', 'REB', 'AST', 'STL', 'BLK', 'TO', 'PTS', 'DD2', 'TD3',
#        'Exp_Ord'],
#       dtype='object')

# %%
wnba["Pos"]
# Out:
# 0        F
# 1      G/F
# 2        G
# 3      G/F
# 4        G
#       ...
# 138      G
# 139      F
# 140      G
# 141    F/C
# 142      G
# Name: Pos, Length: 143, dtype: object

# %% [markdown]
# # Seaborn - Countplot

# %%
import seaborn as sns

sns.countplot(x = "Exp_Ord", hue = "Pos", data = wnba)

plt.show()

# %%
import seaborn as sns

sns.countplot(x = "Exp_Ord", hue = "Pos", data = wnba,
             order = ["Rookie", "Little Experience", "Experienced", "Very Experienced", "Veteran"])

plt.show()

# %%
import seaborn as sns

sns.countplot(x = "Exp_Ord", hue = "Pos", data = wnba,
             order = ["Rookie", "Little Experience", "Experienced", "Very Experienced", "Veteran"],
             hue_order = ["G", "G/F", "C", "F/C", "F"])

plt.show()

# %%
wnba["Age"].mean()
# Out:
# 27.076923076923077

# %%
wnba["MIN"].mean()
# Out:
# 496.97202797202794

# %% [markdown]
# # Lambda

# %%
wnba["Age"].apply(lambda age: "Old" if age >= 27 else "Young")
# Out:
# 0      Young
# 1        Old
# 2      Young
# 3        Old
# 4      Young
#        ...
# 138      Old
# 139      Old
# 140      Old
# 141      Old
# 142      Old
# Name: Age, Length: 143, dtype: object

# %% [markdown]
# # apply

# %%
wnba["age_cat"] = wnba["Age"].apply(lambda age: "Old" if age >= 27 else "Young")
wnba["min_cat"] = wnba["MIN"].apply(lambda Min: "avg or above" if Min >= 497 else "below avg")

# %%
sns.set_theme()

sns.countplot(x = "age_cat", hue = "min_cat", data = wnba)

plt.show()

# %%
wnba.groupby("age_cat")["MIN"].plot.hist()
plt.show()

# %%
wnba.groupby("age_cat")["MIN"].plot.hist()
wnba.groupby("age_cat")["MIN"].plot.hist()
plt.show()

# %%
wnba[wnba["Age"] <= 27]["MIN"].plot.hist(label = "Young")
wnba[wnba["Age"] > 27]["MIN"].plot.hist(label = "Old")
plt.legend()
plt.show()

# %%
wnba[wnba["Age"] <= 27]["MIN"].plot.hist(label = "Young", histtype = "step")
wnba[wnba["Age"] > 27]["MIN"].plot.hist(label = "Old", histtype = "step")
plt.legend()
plt.show()

# %%
wnba[wnba["Age"] <= 27]["MIN"].plot.hist(label = "Young", histtype = "step")
wnba[wnba["Age"] > 27]["MIN"].plot.hist(label = "Old", histtype = "step")
plt.legend(loc = "lower left")   # location
plt.axvline(497, label = "Average", alpha = 0.3)
plt.show()

# %%
wnba["Age"].min()
# Out:
# 21

# %%
wnba["Age"].max()
# Out:
# 36

# %% [markdown]
# # kde Plot

# %%
wnba[wnba["Age"] <= 27]["MIN"].plot.kde(label = "Young")
wnba[wnba["Age"] > 27]["MIN"].plot.kde(label = "Old")
plt.legend(loc = "lower left")   # location
plt.axvline(497, label = "Average", alpha = 0.3)
plt.show()

# %%
wnba["Pos"]
# Out:
# 0        F
# 1      G/F
# 2        G
# 3      G/F
# 4        G
#       ...
# 138      G
# 139      F
# 140      G
# 141    F/C
# 142      G
# Name: Pos, Length: 143, dtype: object

# %%
positions = wnba["Pos"].unique()
positions
# Out:
# array(['F', 'G/F', 'G', 'C', 'F/C'], dtype=object)

# %%
plt.subplot(1, 1, 1)

for pos in positions:
    bol_pos = wnba["Pos"] == pos
    wnba[bol_pos]["Height"].plot.kde(label = pos)
plt.legend()
plt.show()

# %% [markdown]
# # Stripplot

# %%
sns.stripplot(x = "Pos", y = "Height", data = wnba)
plt.show()

# %%
sns.stripplot(x = "Pos", y = "Height", data = wnba, jitter = False)
plt.show()

# %%
wnba["Weight"].describe()
# Out:
# count    142.000000
# mean      78.978873
# std       10.996110
# min       55.000000
# 25%       71.500000
# 50%       79.000000
# 75%       86.000000
# max      113.000000
# Name: Weight, dtype: float64

# %%
wnba["Weight"].plot.hist()
plt.show()

# %% [markdown]
# # Boxplot

# %%
sns.boxplot(x = "Pos", y = "Height", data = wnba) # box and whisker
plt.show()

# %%
sns.boxplot(x = "Pos", y = "Weight", data = wnba, whis = 1.5) 
plt.show()

# %%
wnba[wnba["Pos"] == "F"]["Weight"].describe()
# Out:
# count     33.000000
# mean      83.090909
# std        6.458346
# min       71.000000
# 25%       79.000000
# 50%       82.000000
# 75%       86.000000
# max      104.000000
# Name: Weight, dtype: float64

# %%
iqr = 86 - 79

# %%
value = iqr * 1.5

# %%
value
# Out:
# 10.5

# %%
lower_bound = 79 - (iqr * 1.5)
lower_bound
# Out:
# 68.5

# %%
upper_bound = 86 + (iqr * 1.5)
upper_bound
# Out:
# 96.5

# %%
wnba[wnba["Pos"] == "C"]["Height"].describe()
# Out:
# count     25.000000
# mean     194.920000
# std        4.132392
# min      185.000000
# 25%      193.000000
# 50%      193.000000
# 75%      196.000000
# max      206.000000
# Name: Height, dtype: float64
